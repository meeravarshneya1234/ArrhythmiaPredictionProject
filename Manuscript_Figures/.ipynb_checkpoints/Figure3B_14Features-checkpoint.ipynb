# %%
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
import sys
sys.path.insert(1,'C:/ArrhythmiaPredictionProject/ml_functions/') # include path to ml_functions 
import ML_Pipeline as ml
import warnings 
warnings.simplefilter('ignore')

# %reload_ext autoreload
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Input Data 
filename = 'C:/ArrhythmiaPredictionProject/Manuscript_Data/Population_Feature_Outputs.csv' # file with data 
features = ['Vrest', 'Upstroke', 'Vpeak', 'APD20', 'APD40', 'APD50', 'APD90',
       'TriAP','DCai', 'Capeak', 'CaD50', 'CaD90', 'TriCa', 'dCa']
seed = 134556

# %%
# Output Data 
flag_save = True
folder_save = ''
output_name = 'Test'

# %%
labels = ['IKrBlock_Label','ICaLIncrease_Label','Inject_Label']
for label in labels:
    
    print('------------------------------------------')
    print('Running ' + label)
    ML_Task = ml.ML_Pipeline(filename,label,features,seed)
    df = ML_Task.convert_df()
    df = df.iloc[0:1000]
    ML_Task.train_test_data = train_test_split(df[features], df[label], random_state = seed, test_size = 0.10)        
       
    LR = ML_Task.run_LR()
    SVM = ML_Task.run_SVM()
    KNN = ML_Task.run_KNN()
    RF = ML_Task.run_RF()
    NB = ML_Task.run_NB()
    GB = ML_Task.run_GB()
    XGB = ML_Task.run_XGB()
    ANN = ML_Task.run_ANN()
    
    classifiers = [LR[1], SVM[1], NB, XGB[1], GB[1], RF[1], KNN[1], ANN[1]]
    keys = ['LR','SVM','NB','XGB','GB','RF','KNN','ANN']
    combined_ML_data = ML_Task.create_table(classifiers,keys)

    result_table = combined_ML_data[0]
    metrics = combined_ML_data[1]
    rocs = combined_ML_data[2]
    prob = combined_ML_data[3]
    pred = combined_ML_data[4]
    conf_matrix = combined_ML_data[5]

    result_table
    
    ML_Task.plotting(rocs,result_table)
    ML_Task.flag_save = flag_save
    ML_Task.save_data(output_name,combined_ML_data,keys)
# Out:
# ------------------------------------------
# Running IKrBlock_Label
# ------------------------------------------
# LR Best Params:
# {'C': 100}
# 0.7944444444444445
# ------------------------------------------
# SVM Best Params:
# {'C': 50, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.7300000000000001
# ------------------------------------------
# KNN Best Params:
# {'n_neighbors': 19}
# 0.5460565476190476
# ------------------------------------------
# Random forest Best Params:
# {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 100, 'max_features': 3, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 200}
# 0.668204365079365
# ------------------------------------------
# Gradient Boosting Best Params:
# {'learning_rate': 0.5, 'max_depth': 200, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 200}
# 0.6266666666666667
# ------------------------------------------
# XGBoost Best Params:
# {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 100, 'min_child_weight': 8, 'n_estimators': 100, 'subsample': 0.8}
# 0.6622222222222222
# ------------------------------------------
# ANN Best Params:
# {'activation': 'tanh', 'hidden_layer_sizes': (32, 32, 64), 'learning_rate_init': 0.001, 'solver': 'lbfgs'}
# 0.7277777777777779
# File already exists
# ------------------------------------------
# Running ICaLIncrease_Label
# ------------------------------------------
# LR Best Params:
# {'C': 10}
# 0.8241264353623905
# ------------------------------------------
# SVM Best Params:
# {'C': 10, 'gamma': 1, 'kernel': 'linear'}
# 0.7544444444444445
# ------------------------------------------
# KNN Best Params:
# {'n_neighbors': 19}
# 0.6722928756636621
# ------------------------------------------
# Random forest Best Params:
# {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 100, 'max_features': 3, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 200}
# 0.7479688850475368
# ------------------------------------------
# Gradient Boosting Best Params:
# {'learning_rate': 0.5, 'max_depth': 200, 'max_features': 2, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 100}
# 0.6911111111111111
# ------------------------------------------
# XGBoost Best Params:
# {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 100, 'min_child_weight': 8, 'n_estimators': 200, 'subsample': 0.8}
# 0.7144444444444445
# ------------------------------------------
# ANN Best Params:
# {'activation': 'tanh', 'hidden_layer_sizes': (32, 32), 'learning_rate_init': 0.001, 'solver': 'adam'}
# 0.7477777777777778
# File already exists
# ------------------------------------------
# Running Inject_Label
# ------------------------------------------
# LR Best Params:
# {'C': 100}
# 0.9765857775283703
# ------------------------------------------
# SVM Best Params:
# {'C': 10, 'gamma': 1, 'kernel': 'linear'}
# 0.918888888888889
# ------------------------------------------
# KNN Best Params:
# {'n_neighbors': 19}
# 0.9191150626636737
# ------------------------------------------
# Random forest Best Params:
# {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 100, 'max_features': 3, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 200}
# 0.9681494014216236
# ------------------------------------------
# Gradient Boosting Best Params:
# {'learning_rate': 1, 'max_depth': 100, 'max_features': 2, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 100}
# 0.9
# ------------------------------------------
# XGBoost Best Params:
# {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 100, 'min_child_weight': 8, 'n_estimators': 200, 'subsample': 0.8}
# 0.9011111111111113
# ------------------------------------------
# ANN Best Params:
# {'activation': 'relu', 'hidden_layer_sizes': (32,), 'learning_rate_init': 0.01, 'solver': 'adam'}
# 0.9122222222222224
# File already exists

# %%
# Out:
# File already exists
